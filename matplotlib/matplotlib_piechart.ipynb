# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
subjects = ["Data Structure", "Computer Architecture","DBMS","Computer Networking"]
marks = np.array([78,67,89,70])

# %%
plt.pie(x = marks, labels = subjects, explode = [0.2,0.4,0.1,0.3],shadow = True)
plt.show()
